# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as pltcd 
from textblob import TextBlob

# %%
df_path = "Bitcoin_tweets.csv"
df = pd.read_csv(df_path)

df.head(10)
# Out:
#                                   user_name    user_location  \
# 0                             DeSota Wilson      Atlanta, GA
# 1                                  CryptoND              NaN
# 2                                 Tdlmatias  London, England
# 3                      Crypto is the future              NaN
# 4  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader           Europa
# 5                       ZerrBenz™ ⚔ ✪ 20732    Bkk, Thailand
# 6                               Bitcoin-Bot     Florida, USA
# 7                    Cryptocurrencies / EUR              NaN
# 8                                   Mikcoin              NaN
# 9                             DeSota Wilson      Atlanta, GA
#
#                                     user_description         user_created  \
# 0  Biz Consultant, real estate, fintech, startups...  2009-04-26 20:05:09
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...  2019-10-17 20:12:10
# ...

# %%
# remove nan value row in hastags column
df. dropna(subset = ["hashtags"], inplace=True)
df.head(5)
# Out:
#                                   user_name  user_location  \
# 0                             DeSota Wilson    Atlanta, GA
# 1                                  CryptoND            NaN
# 3                      Crypto is the future            NaN
# 4  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader         Europa
# 5                       ZerrBenz™ ⚔ ✪ 20732  Bkk, Thailand
#
#                                     user_description         user_created  \
# 0  Biz Consultant, real estate, fintech, startups...  2009-04-26 20:05:09
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...  2019-10-17 20:12:10
# 3  I will post a lot of buying signals for BTC tr...  2019-09-28 16:48:12
# 4  Co-founder @RENJERJerky | Forbes 30Under30 | I...  2016-02-03 13:15:55
# 5  I'm a cat slave 🐱 Interested in Blockchain · T...  2010-01-12 07:00:04
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0            8534          7605             4838          False
# ...

# %%
# total value size
print("Tweet Size: ", len(df))
# Out:
# Tweet Size:  38416

# %%
# get only texts
df = df[['text', 'date', 'user_followers']]
df.columns = ['text', 'date', 'followers']
df
# Out:
#                                                     text                 date  \
# 0      Blue Ridge Bank shares halted by NYSE after #b...  2021-02-10 23:59:04
# 1      😎 Today, that's this #Thursday, we will do a "...  2021-02-10 23:58:48
# 3      $BTC A big chance in a billion! Price: \487264...  2021-02-10 23:54:33
# 4      This network is secured by 9 508 nodes as of t...  2021-02-10 23:54:06
# 5      💹 Trade #Crypto on #Binance \n\n📌 Enjoy #Cashb...  2021-02-10 23:53:30
# ...                                                  ...                  ...
# 48577  $BTC pop or drop?\n\n#volatility in 3...2...1....  2021-03-11 22:31:26
# 48578  Bill Gates advised against investing in #Bitco...  2021-03-11 22:30:23
# 48579  #Bitcoin price in US Dollar #BTC $usd #BTCUSD ...  2021-03-11 22:30:04
# 48580  Market Id : BTC-AUD\nLast Price :74260.91\n24 ...  2021-03-11 22:30:02
# 48581    Bitcoin retesting ATH ❤️\n#Bitcoin #btc #Crypto  2021-03-11 22:29:39
#
#        followers
# ...

# %%
# create a function to clean the tweets
def cleanTwt(twt):
    twt = re.sub("#bitcoin", 'bitcoin', twt) # removes the '#' from bitcoin
    twt = re.sub("#Bitcoin", 'Bitcoin', twt) # removes the '#' from Bitcoin
    twt = re.sub('#[A-Za-z0-9]+', '', twt) # removes any string with a '#'
    twt = re.sub('\\n', '', twt) # removes the '\n' string
    twt = re.sub('https:\/\/\S+', '', twt) # removes any hyperlinks
    return twt

# %%
df['cleaned_tweets'] = df['text'].apply(cleanTwt)
df
# Out:
#                                                     text                 date  \
# 0      Blue Ridge Bank shares halted by NYSE after #b...  2021-02-10 23:59:04
# 1      😎 Today, that's this #Thursday, we will do a "...  2021-02-10 23:58:48
# 3      $BTC A big chance in a billion! Price: \487264...  2021-02-10 23:54:33
# 4      This network is secured by 9 508 nodes as of t...  2021-02-10 23:54:06
# 5      💹 Trade #Crypto on #Binance \n\n📌 Enjoy #Cashb...  2021-02-10 23:53:30
# ...                                                  ...                  ...
# 48577  $BTC pop or drop?\n\n#volatility in 3...2...1....  2021-03-11 22:31:26
# 48578  Bill Gates advised against investing in #Bitco...  2021-03-11 22:30:23
# 48579  #Bitcoin price in US Dollar #BTC $usd #BTCUSD ...  2021-03-11 22:30:04
# 48580  Market Id : BTC-AUD\nLast Price :74260.91\n24 ...  2021-03-11 22:30:02
# 48581    Bitcoin retesting ATH ❤️\n#Bitcoin #btc #Crypto  2021-03-11 22:29:39
#
# ...

# %%
# create a function to get subjectivity
def getSubjectivity(twt):
    return TextBlob(twt).sentiment.subjectivity

# create a function to get the polarity
def getPolarity(twt):
    return TextBlob(twt).sentiment.polarity

# create two new columns called "Subjectivity" & "Polarity"
df['subjectivity'] = df['cleaned_tweets'].apply(getSubjectivity)
df['polarity'] = df['cleaned_tweets'].apply(getPolarity)

# %%
df.head(5)
# Out:
#                                                 text                 date  \
# 0  Blue Ridge Bank shares halted by NYSE after #b...  2021-02-10 23:59:04
# 1  😎 Today, that's this #Thursday, we will do a "...  2021-02-10 23:58:48
# 3  $BTC A big chance in a billion! Price: \487264...  2021-02-10 23:54:33
# 4  This network is secured by 9 508 nodes as of t...  2021-02-10 23:54:06
# 5  💹 Trade #Crypto on #Binance \n\n📌 Enjoy #Cashb...  2021-02-10 23:53:30
#
#    followers                                     cleaned_tweets  subjectivity  \
# 0       8534  Blue Ridge Bank shares halted by NYSE after bi...           0.1
# 1       6769  😎 Today, that's this , we will do a "🎬 Take 2"...           0.0
# 3        625  $BTC A big chance in a billion! Price: \487264...           0.1
# 4       1249  This network is secured by 9 508 nodes as of t...           0.1
# 5        742  💹 Trade  on  📌 Enjoy  10% of the Trading fee📌 ...           0.5
#
#    polarity
# 0       0.0
# 1       0.0
# ...

# %%
# create a function get the sentiment text
def getSentiment(score):
    if score < 0:
        return "negative"
    elif score == 0:
        return "neutral"
    else:
        return "positive"

# %%
# create a column to store the text sentiment
df['sentiment'] = df['polarity'].apply(getSentiment)

# show the data
df.head()
# Out:
#                                                 text                 date  \
# 0  Blue Ridge Bank shares halted by NYSE after #b...  2021-02-10 23:59:04
# 1  😎 Today, that's this #Thursday, we will do a "...  2021-02-10 23:58:48
# 3  $BTC A big chance in a billion! Price: \487264...  2021-02-10 23:54:33
# 4  This network is secured by 9 508 nodes as of t...  2021-02-10 23:54:06
# 5  💹 Trade #Crypto on #Binance \n\n📌 Enjoy #Cashb...  2021-02-10 23:53:30
#
#    followers                                     cleaned_tweets  subjectivity  \
# 0       8534  Blue Ridge Bank shares halted by NYSE after bi...           0.1
# 1       6769  😎 Today, that's this , we will do a "🎬 Take 2"...           0.0
# 3        625  $BTC A big chance in a billion! Price: \487264...           0.1
# 4       1249  This network is secured by 9 508 nodes as of t...           0.1
# 5        742  💹 Trade  on  📌 Enjoy  10% of the Trading fee📌 ...           0.5
#
#    polarity sentiment
# 0       0.0   neutral
# ...

# %%
df = df[['date', 'cleaned_tweets', 'followers']]
df.columns = ['time', 'tweets', 'followers']
df
# Out:
#                       time                                             tweets  \
# 0      2021-02-10 23:59:04  Blue Ridge Bank shares halted by NYSE after bi...
# 1      2021-02-10 23:58:48  😎 Today, that's this , we will do a "🎬 Take 2"...
# 3      2021-02-10 23:54:33  $BTC A big chance in a billion! Price: \487264...
# 4      2021-02-10 23:54:06  This network is secured by 9 508 nodes as of t...
# 5      2021-02-10 23:53:30  💹 Trade  on  📌 Enjoy  10% of the Trading fee📌 ...
# ...                    ...                                                ...
# 48577  2021-03-11 22:31:26    $BTC pop or drop? in 3...2...1... Bitcoin  or
# 48578  2021-03-11 22:30:23  Bill Gates advised against investing in Bitcoi...
# 48579  2021-03-11 22:30:04  Bitcoin price in US Dollar  $usd  $XBT  BTC Pr...
# 48580  2021-03-11 22:30:02  Market Id : BTC-AUDLast Price :74260.9124 Hour...
# 48581  2021-03-11 22:29:39                  Bitcoin retesting ATH ❤️Bitcoin
#
#        followers
# 0           8534
# ...

# %%
df = df[df['followers'] > 100000]
df
# Out:
#                       time                                             tweets  \
# 479    2021-02-10 20:24:47  Someone bought a Tesla Model S in 2013 for 91....
# 880    2021-02-10 18:02:53   is our new Bitcoin and @Liquid_BTC wallet des...
# 1100   2021-02-10 16:45:01  How To Potentially Profit From Bitcoin Without...
# 1326   2021-02-10 15:46:26  $BTCUSD Bitcoin  Going down right through the ...
# 1411   2021-02-10 15:23:58  "It has to be part of the menu," says @JimCram...
# ...                    ...                                                ...
# 47214  2021-03-12 08:15:01  30% of British investors aren't planning to in...
# 47810  2021-03-12 04:12:36  So many @investvoyager  parties, people are bo...
# 48012  2021-03-12 02:29:21  🥇 Casino via  ⟶  √Take a look at some of our b...
# 48126  2021-03-12 01:29:01  With Bitcoin on everyone's tongue, have you vi...
# 48423  2021-03-11 23:30:08  Bitcoin banknotes? What do you think about thi...
#
#        followers
# ...

# %%
df = df.sort_values(by = "time")
df
# Out:
#                     time                                             tweets  \
# 76   2021-02-05 16:34:06  It's never too late to start investing in ! Us...
# 75   2021-02-05 18:15:09  Have you seen our Bitcoin Analytics Page? Lear...
# 74   2021-02-05 22:17:54  This week in :1. @kucoincom list  with  &amp; ...
# 73   2021-02-06 01:32:35  Just fielded another call from a manufacturer ...
# 72   2021-02-06 04:34:01  : Bitcoin is trading at ~$39.5k/, within 10% o...
# ..                   ...                                                ...
# 160  2021-03-12 12:06:07  🥇 Casino via  ⟶  √Take a look at some of our b...
# 159  2021-03-12 12:48:48  What To Know About Bitcoin Faucets To Earn BTC...
# 158  2021-03-12 14:12:07  🥇 Casino via  ⟶  √Take a look at some of our b...
# 157  2021-03-12 20:08:23  Microstrategy adds another 15 million worth of...
# 156  2021-03-12 22:49:55  🌎 Today bitcoin has now transferred more than ...
#
#      followers
# 76      265540
# 75      731739
# ...

# %%
df = df.reset_index(drop = True)
df
# Out:
#                     time                                             tweets  \
# 0    2021-02-05 16:34:06  It's never too late to start investing in ! Us...
# 1    2021-02-05 18:15:09  Have you seen our Bitcoin Analytics Page? Lear...
# 2    2021-02-05 22:17:54  This week in :1. @kucoincom list  with  &amp; ...
# 3    2021-02-06 01:32:35  Just fielded another call from a manufacturer ...
# 4    2021-02-06 04:34:01  : Bitcoin is trading at ~$39.5k/, within 10% o...
# ..                   ...                                                ...
# 164  2021-03-12 12:06:07  🥇 Casino via  ⟶  √Take a look at some of our b...
# 165  2021-03-12 12:48:48  What To Know About Bitcoin Faucets To Earn BTC...
# 166  2021-03-12 14:12:07  🥇 Casino via  ⟶  √Take a look at some of our b...
# 167  2021-03-12 20:08:23  Microstrategy adds another 15 million worth of...
# 168  2021-03-12 22:49:55  🌎 Today bitcoin has now transferred more than ...
#
#      followers
# 0       265540
# 1       731739
# ...

# %%
import os  
os.makedirs('tweets_btc', exist_ok=True)  
df.to_csv('tweets_btc/btc_tweets.csv', index=False)
